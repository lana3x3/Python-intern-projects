# %%
# !pip install mediapipe
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.6/35.6 MB 15.8 MB/s eta 0:00:00
# ...

# %%
import cv2
import mediapipe as mp

# %%
# prompt: import time

import time
# No need to import cv2 or mediapipe again if already imported.
# and pip install mediapipe is not necessary as it is done in the previous code block


# Example usage of time module (assuming you want to measure execution time)
start_time = time.time()

# Your code goes here...
time.sleep(2)

end_time = time.time()
elapsed_time = end_time - start_time
print(f"Elapsed time: {elapsed_time:.2f} seconds")
# Out:
# Elapsed time: 2.00 seconds

# %%
mp_face_detection=mp.solutions.face_detection

# %%
mp_drawing=mp.solutions.drawing_utils

# %%
cap=cv2.VideoCapture

# %%
open
# Out:
# <function io.open(file, mode='r', buffering=-1, encoding=None, errors=None, newline=None, closefd=True, opener=None)>
